# %%
import os
from dotenv import load_dotenv
load_dotenv()
database_url = os.getenv("DATABASE_URL")
database_url
# Out:
# 'postgres://user:password@localhost/dbname'

# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb
data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = database_url

# above, either remove your credentials or delete the mongoDB resource bofore pushing it to github.

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]
# Out:
# ---------------------------------------------------------------------------
# InvalidURI                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 client = pymongo.MongoClient(CONNECTION_URL)
#       2 data_base = client[DB_NAME]
#       3 collection = data_base[COLLECTION_NAME]
#
# File c:\desktop\vikas_das\MLOps-project1\vehi_venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:804, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     799 for entity in self._host:
#     800     # A hostname can only include a-z, 0-9, '-' and '.'. If we find a '/'
#     801     # it must be a URI,
#     802     # https://en.wikipedia.org/wiki/Hostname#Restrictions_on_valid_host_names
#     803     if "/" in entity:
# --> 804         res = _validate_uri(
#     805             entity,
#     806             port,
#     807             validate=True,
#     808             warn=True,
#     809             normalize=False,
#     810             srv_max_hosts=srv_max_hosts,
#     811         )
#     812         is_srv = entity.startswith(SRV_SCHEME)
#     813         self._seeds.update(res["nodelist"])
#
# File c:\desktop\vikas_das\MLOps-project1\vehi_venv\Lib\site-packages\pymongo\uri_parser_shared.py:533, in _validate_uri(uri, default_port, validate, warn, normalize, srv_max_hosts)
#     531     scheme_free = uri[SRV_SCHEME_LEN:]
#     532 else:
# --> 533     raise InvalidURI(f"Invalid URI scheme: URI must begin with '{SCHEME}' or '{SRV_SCHEME}'")
#     535 if not scheme_free:
#     536     raise InvalidURI("Must provide at least one hostname or IP")
#
# InvalidURI: Invalid URI scheme: URI must begin with 'mongodb://' or 'mongodb+srv://'
